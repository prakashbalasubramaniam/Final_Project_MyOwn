# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import json
import urllib.request
import os
from flask import render_template, request, redirect, app

# %%
def do_something_pretty(jsondata):
    """We want to process the AML json result to be more human readable and understandable"""
    import itertools # for flattening a list of tuples below

    # We only want the first array from the array of arrays under "Value" 
    # - it's cluster assignment and distances from all centroid centers from k-means model
    value = jsondata["Results"]["output1"]["value"]["Values"][0]
    
    print(value)

#     output='The response from Customer : ' +value[8]

    return value

# %%
ML_KEY=os.environ.get('API_KEY', "UXjxG8o1TBboTNmk3uiI5Hc0IaB+qAyS8g8JDd27MMvmmdU88VN/vgo7I6cWV4maPuYE2xDfvCVuG6GklBVxsQ==")
ML_URL = os.environ.get('URL', "https://ussouthcentral.services.azureml.net/workspaces/6f51976e43574b7eb7a64306a5d08410/services/ec1670a4b69d467584b89d1107c2480d/execute?api-version=2.0&details=true")

# %%
# state = 'Washington'
# custlifetime = 2763
# coverage = 'Basic'
# claimamount = 384
# vehicleclass = 'Two-Door Car'
# vehiclesize = 'Medsize'

# state = 'Arizona'
# custlifetime = 6979.535903
# coverage = 'Extended'
# claimamount = 1131.464935
# vehicleclass = 'Four-Door Car'
# vehiclesize = 'Medsize'

# state = 'California'
# custlifetime = 7645.861827
# coverage = 'Extended'
# claimamount = 529.881344
# vehicleclass = 'SUV'
# vehiclesize = 'Medsize'

state = 'California'
custlifetime = [0, 10000, 500]
coverage = 'Extended'
claimamount = 529.881344
vehicleclass = 'SUV'
vehiclesize = 'Medsize'

x_data = []
y_data = []

# %%
for i in range (custlifetime[0], custlifetime[1]+custlifetime[2], custlifetime[2]):
    data = {"Inputs": {"input1": {"ColumnNames": ["State","Customer Lifetime Value","Coverage","Monthly Premium Auto",
                                                  "Total Claim Amount","Vehicle Class","Vehicle Size"],
                                  "Values": [[state,i,coverage,"",claimamount,vehicleclass,vehiclesize]]
                                 }
                      },
            "GlobalParameters": {}
           }
    # Serialize the input data into json string
    body = str.encode(json.dumps(data))
    HEADERS = {'Content-Type':'application/json', 'Authorization':('Bearer '+ ML_KEY)}
    req = urllib.request.Request(ML_URL, body, HEADERS)
    response = urllib.request.urlopen(req)
    respdata = response.read()
    result = json.loads(str(respdata, 'utf-8'))
    result = do_something_pretty(result)
    x_data.append(i)
    temp = round(float(result[7]),2)
    y_data.append(temp)
# Out:
# ['California', '0', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.245616436005']
# ['California', '500', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.26482373476']
# ['California', '1000', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.284039884806']
# ['California', '1500', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.303264886141']
# ['California', '2000', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.322481036186']
# ['California', '2500', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.341706037521']
# ['California', '3000', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.360931038857']
# ['California', '3500', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.380164891481']
# ['California', '4000', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.399398744106']
# ['California', '4500', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.418632596731']
# ['California', '5000', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.437875300646']
# ['California', '5500', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.457109153271']
# ['California', '6000', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.476351857185']
# ['California', '6500', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.49560341239']
# ['California', '7000', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.514854967594']
# ['California', '7500', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.534106522799']
# ['California', '8000', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.553358078003']
# ['California', '8500', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.572618484497']
# ['California', '9000', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.591878890991']
# ['California', '9500', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.611139297485']
# ['California', '10000', 'Extended', None, '529.881344', 'SUV', 'Medsize', '133.630408555269']

# %%
print(y_data)
# Out:
# [133.25, 133.26, 133.28, 133.3, 133.32, 133.34, 133.36, 133.38, 133.4, 133.42, 133.44, 133.46, 133.48, 133.5, 133.51, 133.53, 133.55, 133.57, 133.59, 133.61, 133.63]

# %%
fig_one = plt.figure(figsize=(10,10))
plt.plot(x_data, y_data, c="blue", linestyle='dashed', marker='x', label="Predicted Monthly Premium")
plt.grid()
plt.legend(loc='lower right')
plt.title("Customer Lifetime Value vs Monthly Premium Plot")
plt.xlabel('Customer Lifetime Value')
plt.ylabel('Predicted Monthly Premium $')
plt.show()
# fig_one.savefig('cust_lifetime_response.png')

# %%
state = 'California'
custlifetime = 7645.861827
coverage = 'Premium'
claimamount = [0, 10000, 500]
vehicleclass = 'SUV'
vehiclesize = 'Medsize'

x_data_two = []
y_data_two = []

# %%
for i in range (claimamount[0], claimamount[1]+claimamount[2], claimamount[2]):
    data = {"Inputs": {"input1": {"ColumnNames": ["State","Customer Lifetime Value","Coverage","Monthly Premium Auto",
                                                  "Total Claim Amount","Vehicle Class","Vehicle Size"],
                                  "Values": [[state,custlifetime,coverage,"",i,vehicleclass,vehiclesize]]
                                 }
                      },
            "GlobalParameters": {}
           }
    # Serialize the input data into json string
    body = str.encode(json.dumps(data))
    HEADERS = {'Content-Type':'application/json', 'Authorization':('Bearer '+ ML_KEY)}
    req = urllib.request.Request(ML_URL, body, HEADERS)
    response = urllib.request.urlopen(req)
    respdata = response.read()
    result = json.loads(str(respdata, 'utf-8'))
    result = do_something_pretty(result)
    x_data_two.append(i)
    temp = round(float(result[7]),2)
    y_data_two.append(temp)
# Out:
# ['California', '7645.861827', 'Premium', None, '0', 'SUV', 'Medsize', '165.87377178669']
# ['California', '7645.861827', 'Premium', None, '500', 'SUV', 'Medsize', '167.210900723934']
# ['California', '7645.861827', 'Premium', None, '1000', 'SUV', 'Medsize', '168.558792829514']
# ['California', '7645.861827', 'Premium', None, '1500', 'SUV', 'Medsize', '169.917572021484']
# ['California', '7645.861827', 'Premium', None, '2000', 'SUV', 'Medsize', '171.287291407585']
# ['California', '7645.861827', 'Premium', None, '2500', 'SUV', 'Medsize', '172.668057203293']
# ['California', '7645.861827', 'Premium', None, '3000', 'SUV', 'Medsize', '174.059940218925']
# ['California', '7645.861827', 'Premium', None, '3500', 'SUV', 'Medsize', '175.46306437254']
# ['California', '7645.861827', 'Premium', None, '4000', 'SUV', 'Medsize', '176.877482771873']
# ['California', '7645.861827', 'Premium', None, '4500', 'SUV', 'Medsize', '178.303319334984']
# ['California', '7645.861827', 'Premium', None, '5000', 'SUV', 'Medsize', '179.740627169609']
# ['California', '7645.861827', 'Premium', None, '5500', 'SUV', 'Medsize', '181.189530193806']
# ['California', '7645.861827', 'Premium', None, '6000', 'SUV', 'Medsize', '182.650116920471']
# ['California', '7645.861827', 'Premium', None, '6500', 'SUV', 'Medsize', '184.122475862503']
# ['California', '7645.861827', 'Premium', None, '7000', 'SUV', 'Medsize', '185.606713235378']
# ['California', '7645.861827', 'Premium', None, '7500', 'SUV', 'Medsize', '187.102899849415']
# ['California', '7645.861827', 'Premium', None, '8000', 'SUV', 'Medsize', '188.611159622669']
# ['California', '7645.861827', 'Premium', None, '8500', 'SUV', 'Medsize', '190.131563365459']
# ['California', '7645.861827', 'Premium', None, '9000', 'SUV', 'Medsize', '191.664234995842']
# ['California', '7645.861827', 'Premium', None, '9500', 'SUV', 'Medsize', '193.209245324135']
# ['California', '7645.861827', 'Premium', None, '10000', 'SUV', 'Medsize', '194.766735970974']

# %%
fig_two = plt.figure(figsize=(10,10))
plt.plot(x_data_two, y_data_two, c="blue", linestyle='dashed', marker='x', label="Predicted Monthly Premium")
plt.grid()
plt.legend(loc='lower right')
plt.title("Customer Total Claim Value vs Monthly Premium Plot")
plt.xlabel('Customer Total Claim Value $')
plt.ylabel('Predicted Monthly Premium $')
plt.show()
# fig_one.savefig('cust_lifetime_response.png')

# %%
cali_basic_y_data = y_data_two

# %%
cali_ext_y_data = y_data_two

# %%
cali_premium_y_data = y_data_two
# Out:
# [106.16, 107.01, 107.88, 108.75, 109.62, 110.51, 111.4, 112.3, 113.2, 114.11, 115.03, 115.96, 116.9, 117.84, 118.79, 119.75, 120.71, 121.68, 122.66, 123.65, 124.65] [132.41, 133.48, 134.55, 135.64, 136.73, 137.83, 138.94, 140.06, 141.19, 142.33, 143.48, 144.63, 145.8, 146.98, 148.16, 149.35, 150.56, 151.77, 153.0, 154.23, 155.47] [165.87, 167.21, 168.56, 169.92, 171.29, 172.67, 174.06, 175.46, 176.88, 178.3, 179.74, 181.19, 182.65, 184.12, 185.61, 187.1, 188.61, 190.13, 191.66, 193.21, 194.77]

# %%
cali_x_data = x_data_two

# %%
print(cali_x_data, cali_basic_y_data, cali_ext_y_data, cali_premium_y_data)
# Out:
# [0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500, 7000, 7500, 8000, 8500, 9000, 9500, 10000] [106.16, 107.01, 107.88, 108.75, 109.62, 110.51, 111.4, 112.3, 113.2, 114.11, 115.03, 115.96, 116.9, 117.84, 118.79, 119.75, 120.71, 121.68, 122.66, 123.65, 124.65] [132.41, 133.48, 134.55, 135.64, 136.73, 137.83, 138.94, 140.06, 141.19, 142.33, 143.48, 144.63, 145.8, 146.98, 148.16, 149.35, 150.56, 151.77, 153.0, 154.23, 155.47] [165.87, 167.21, 168.56, 169.92, 171.29, 172.67, 174.06, 175.46, 176.88, 178.3, 179.74, 181.19, 182.65, 184.12, 185.61, 187.1, 188.61, 190.13, 191.66, 193.21, 194.77]
